# %% [markdown]
# # User/Query Segmentation using Few-shot classifier or Clustering

# %% [markdown]
# ## Outline

# %% [markdown]
# - **Analyze User Queries**: Perform topic modeling or batch classification to identify inventory or capability issues.
#   - Use BERTTopic modeling, RAGClassifier using retrieval model to explore RHEL7 problem statements.
# - **Evaluate Answer Quality**: Identify examples of good and bad responses to guide improvments in the system's response quality.
# - **Implement Audit feedback mechanisms**:
#   1. Implement user feedback UI
#   2. Assess how often users use the thumbs-up and thumbs-down buttons for feedback.
#   3. Analyze if the feedback mechanism is effective and consider changes if necessary (e.g. larger buttons, respositioning)
# - **Make step-wise improvements**: Discuss with your team where to make improvements
#   1. What Metadata is missing?
#   2. What filters are missing?
#   3. What indices are missing?
